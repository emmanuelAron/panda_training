# %% [markdown]
# <a href="https://colab.research.google.com/github/emmanuelAron/panda_training/blob/main/Working_with_dataframes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color='green'>Working with Dataframes:</font>

# %%
import pandas as pd
import numpy as np

#lists
names = ['Emma', 'Celine' , 'Bryan', 'Toto', 'Nicole', 'Tilda']
ages =  [44, 41, 25, 56, 33, 9]
married = [False,True , True , True , False , True]

# %%
#Panda series
ser = pd.Series(names, name='name')

# %%
ser
# Out:
# 0      Emma
# 1    Celine
# 2     Bryan
# 3      Toto
# 4    Nicole
# 5     Tilda
# Name: name, dtype: object

# %%
#Panda dataframe
df = pd.DataFrame({'name' : names , 'age':ages , 'married':married})

# %%
df
# Out:
#      name  age  married
# 0    Emma   44    False
# 1  Celine   41     True
# 2   Bryan   25     True
# 3    Toto   56     True
# 4  Nicole   33    False
# 5   Tilda    9     True
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
df.iloc[2,0]
# Out:
# 'Bryan'

# %%
# number of dimensions
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (6, 3)

# %%
df.name
# Out:
# 0      Emma
# 1    Celine
# 2     Bryan
# 3      Toto
# 4    Nicole
# 5     Tilda
# Name: name, dtype: object

# %%
#return a serie : column names and their types
df.dtypes
# Out:
# name       object
# age         int64
# married      bool
# dtype: object

# %% [markdown]
# Creating a Dataframe

# %%
df
# Out:
#      name  age  married
# 0    Emma   44    False
# 1  Celine   41     True
# 2   Bryan   25     True
# 3    Toto   56     True
# 4  Nicole   33    False
# 5   Tilda    9     True

# %%
ages
# Out:
# [44, 41, 25, 56, 33, 9]

# %%
pd.DataFrame({'name':names,'age':ages,'married':married})
# Out:
#      name  age  married
# 0    Emma   44    False
# 1  Celine   41     True
# 2   Bryan   25     True
# 3    Toto   56     True
# 4  Nicole   33    False
# 5   Tilda    9     True

# %%
len(names)
# Out:
# 6

# %% [markdown]
# Reading at nutrition Data

# %%
dataurl = 'https://andybek.com/pandas-nutrition'
nutrition = pd.read_csv(dataurl)

# %%
nutrition
# Out:
#       Unnamed: 0                                               name  \
# 0              0                                         Cornstarch
# 1              1                                       Nuts, pecans
# 2              2                                      Eggplant, raw
# 3              3                                     Teff, uncooked
# 4              4                                    Sherbet, orange
# ...          ...                                                ...
# 8784        8784  Beef, raw, all grades, trimmed to 0" fat, sepa...
# 8785        8785  Lamb, cooked, separable lean only, composite o...
# 8786        8786  Lamb, raw, separable lean and fat, composite o...
# 8787        8787  Beef, raw, all grades, trimmed to 0" fat, sepa...
# 8788        8788  Beef, raw, all grades, trimmed to 0" fat, sepa...
#
#      serving_size  calories total_fat saturated_fat cholesterol    sodium  \
# 0           100 g       381      0.1g           NaN           0   9.00 mg
# ...

# %%
nutrition.head(10)
# Out:
#    Unnamed: 0                name serving_size  calories total_fat  \
# 0           0          Cornstarch        100 g       381      0.1g
# 1           1        Nuts, pecans        100 g       691       72g
# 2           2       Eggplant, raw        100 g        25      0.2g
# 3           3      Teff, uncooked        100 g       367      2.4g
# 4           4     Sherbet, orange        100 g       144        2g
# 5           5    Cauliflower, raw        100 g        25      0.3g
# 6           6    Taro leaves, raw        100 g        42      0.7g
# 7           7   Lamb, raw, ground        100 g       282       23g
# 8           8   Cheese, camembert        100 g       300       24g
# 9           9  Vegetarian fillets        100 g       290       18g
#
#   saturated_fat cholesterol     sodium  choline      folate  ...      fat  \
# 0           NaN           0    9.00 mg   0.4 mg    0.00 mcg  ...   0.05 g
# 1          6.2g           0    0.00 mg  40.5 mg   22.00 mcg  ...  71.97 g
# ...

# %%
nutrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Data columns (total 77 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   8789 non-null   int64
#  1   name                         8789 non-null   object
#  2   serving_size                 8789 non-null   object
#  3   calories                     8789 non-null   int64
#  4   total_fat                    8789 non-null   object
#  5   saturated_fat                7199 non-null   object
#  6   cholesterol                  8789 non-null   object
#  7   sodium                       8789 non-null   object
#  8   choline                      8789 non-null   object
#  9   folate                       8789 non-null   object
#  10  folic_acid                   8789 non-null   object
#  11  niacin                       8789 non-null   object
#  12  pantothenic_acid             8789 non-null   object
# ...

# %%
nutrition.info(verbose=False,memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8789 entries, 0 to 8788
# Columns: 77 entries, Unnamed: 0 to water
# dtypes: int64(3), object(74)
# memory usage: 39.2 MB
